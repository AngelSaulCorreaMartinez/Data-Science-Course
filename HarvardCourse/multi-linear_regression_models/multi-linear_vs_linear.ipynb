# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from helper import fit_and_plot_linear, fit_and_plot_multi

# %%
#Read and clean file
df = pd.read_csv('../data_sets/Advertising.csv')
df = df.drop('Unnamed: 0', axis=1)

df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
#Define an empity pandas df to store the r-squared value associated with each predictor
#for both the train and test  split

df_results = pd.DataFrame(columns=['Predictor', 'R2 Train', 'R2 Test'])

# %%
# For each predictor in the dataframe, call the function "fit_and_plot_linear()"
# from the helper file with the predictor as a parameter to the function

# This function will split the data into train and test split, fit a linear model
# on the train data and compute the R-squared value on both the train and test data

r2_tv_train, r2_tv_test = fit_and_plot_linear(df[['TV']])
r2_radio_train, r2_radio_test = fit_and_plot_linear(df[['Radio']])
r2_newspaper_train, r2_newspaper_test = fit_and_plot_linear(df[['Newspaper']])

# %%
# Call the function "fit_and_plot_multi()" from the helper to fit a multilinear model
# on the train data and compute the R-squared value on both the train and test data

r2_all_train, r2_all_test = fit_and_plot_multi()

# %%
### edTest(test_dataframe) ###

# Store the R-squared values for all models
# in the dataframe intialized above

df_results.loc[0] = ['TV', r2_tv_train, r2_tv_test]
df_results.loc[1] = ['Radio', r2_radio_train, r2_radio_test]
df_results.loc[2] = ['Newspaper', r2_newspaper_train, r2_newspaper_test]
df_results.loc[3] = ['Multi-linear', r2_all_train, r2_all_test]

# Take a quick look at the dataframe
df_results.head()
# Out:
#       Predictor  R2 Train   R2 Test
# 0            TV  0.591167  0.676695
# 1         Radio  0.350906  0.263431
# 2     Newspaper  0.056584  0.029872
# 3  Multi-linear  0.895701  0.899438
